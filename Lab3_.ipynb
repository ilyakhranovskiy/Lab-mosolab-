# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyakhranovskiy/Lab-mosolab-/blob/main/Lab3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img_chess= cv2.imread("Lab3_chess100.png", cv2.IMREAD_GRAYSCALE)
img_half= cv2.imread("Lab3_half100.png", cv2.IMREAD_GRAYSCALE)

hist_half = cv2.calcHist([img_half], [0], None, [256], [0, 256])
hist_chess = cv2.calcHist([img_chess], [0], None, [256], [0, 256])

plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(img_half, cmap = 'gray');
plt.subplot(122)
plt.plot(hist_half); plt.xlim([0, 255]); plt.grid(); plt.show();

plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(img_chess, cmap = 'gray');
plt.subplot(122)
plt.plot(hist_chess); plt.xlim([0, 255]); plt.grid(); plt.show();

kernel3 = np.ones((3,3),np.float32) / (3 * 3)
kernel5 = np.ones((5,5),np.float32) / (5 * 5)
kernel9 = np.ones((9,9), np.float32) / (9 * 9)
kernel15 = np.ones((15,15), np.float32) / (15 * 15)

blur_half3= cv2.filter2D(img_half, -1, kernel3)
blur_half5= cv2.filter2D(img_half, -1, kernel5)
blur_half9= cv2.filter2D(img_half, -1, kernel9)
blur_half15= cv2.filter2D(img_half, -1, kernel15)

blur_chess3 = cv2.filter2D(img_chess, -1, kernel3)
blur_chess5 = cv2.filter2D(img_chess, -1, kernel5)
blur_chess9 = cv2.filter2D(img_chess, -1, kernel9)
blur_chess15 = cv2.filter2D(img_chess, -1, kernel15)

blur_half3_hist= cv2.calcHist([blur_half3], [0], None, [256], [0, 256])
blur_half5_hist= cv2.calcHist([blur_half5], [0], None, [256], [0, 256])
blur_half9_hist= cv2.calcHist([blur_half9], [0], None, [256], [0, 256])
blur_half15_hist= cv2.calcHist([blur_half15], [0], None, [256], [0, 256])

blur_chess3_hist=cv2.calcHist([blur_chess3], [0], None, [256], [0, 256])
blur_chess5_hist=cv2.calcHist([blur_chess5], [0], None, [256], [0, 256])
blur_chess9_hist= cv2.calcHist([blur_chess9], [0], None, [256], [0, 256])
blur_chess15_hist=cv2.calcHist([blur_chess15], [0], None, [256], [0, 256])


plt.figure(figsize=(30,30))
plt.subplot(421),plt.imshow(blur_half3),plt.title('Blur half 3x3')
plt.xticks([]), plt.yticks([])
plt.subplot(422),plt.plot(blur_half3_hist ),plt.title('Blur half 3x3')
plt.xticks([]), plt.yticks([])
plt.subplot(423),plt.imshow(blur_half5),plt.title('Blur half 5x5')
plt.xticks([]), plt.yticks([])
plt.subplot(424),plt.plot(blur_half5_hist ),plt.title('Blur half 5x5')
plt.xticks([]), plt.yticks([])
plt.subplot(425),plt.imshow(blur_half9),plt.title('Blur half 9x9')
plt.xticks([]), plt.yticks([])
plt.subplot(426),plt.plot(blur_half9_hist ),plt.title('Blur half 9x9')
plt.xticks([]), plt.yticks([])
plt.subplot(427),plt.imshow(blur_half15),plt.title('Blur half 15x15')
plt.xticks([]), plt.yticks([])
plt.subplot(428),plt.plot(blur_half15_hist ),plt.title('Blur half 15x15')
plt.xticks([]), plt.yticks([])


plt.figure(figsize=(30,30))
plt.subplot(421),plt.imshow(blur_chess3),plt.title('Blur chess 3x3')
plt.xticks([]), plt.yticks([])
plt.subplot(422),plt.plot(blur_chess3_hist ),plt.title('Blur chess 3x3')
plt.xticks([]), plt.yticks([])
plt.subplot(423),plt.imshow(blur_chess5),plt.title('Blur chess 5x5')
plt.xticks([]), plt.yticks([])
plt.subplot(424),plt.plot(blur_chess5_hist ),plt.title('Blur chess 5x5')
plt.xticks([]), plt.yticks([])
plt.subplot(425),plt.imshow(blur_chess9),plt.title('Blur chess 9x9')
plt.xticks([]), plt.yticks([])
plt.subplot(426),plt.plot(blur_chess9_hist ),plt.title('Blur chess 9x9')
plt.xticks([]), plt.yticks([])
plt.subplot(427),plt.imshow(blur_chess15),plt.title('Blur chess 15x15')
plt.xticks([]), plt.yticks([])
plt.subplot(428),plt.plot(blur_chess15_hist ),plt.title('Blur chess 15x15')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))
